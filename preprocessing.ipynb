# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\numpy\core\__init__.py:29: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\numpy\.libs\libopenblas.IPBC74C7KURV7CB2PKT5Z5FNR3SIBV4J.gfortran-win_amd64.dll
# C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
df = pd.read_csv('scraper/bundesliga-2018-2018.csv', parse_dates=True)

# %%
df.head()
# Out:
#    Unnamed: 0 competition            date gameday     guest_coach  \
# 0           0  Bundesliga  Fr. 27.07.2018       1  Karl Daxbacher
# 1           1  Bundesliga  Sa. 04.08.2018       2             NaN
# 2           2  Bundesliga  Sa. 11.08.2018       3  Karl Daxbacher
# 3           3  Bundesliga  Sa. 18.08.2018       4             NaN
# 4           4  Bundesliga  So. 26.08.2018       5  Karl Daxbacher
#
#   guest_game_system  guest_team_id      guest_team_name      home_coach  \
# 0       5-4-1 flach           2444  FC Wacker Innsbruck             NaN
# 1               NaN            122        SK Sturm Graz  Karl Daxbacher
# 2          4-2-3-1            2444  FC Wacker Innsbruck             NaN
# 3               NaN           2662       SKN St. Pölten  Karl Daxbacher
# 4          4-2-3-1            2444  FC Wacker Innsbruck             NaN
#
#   home_game_system  home_team_id       home_team_name  \
# 0              NaN            14      FK Austria Wien
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0 competition            date  gameday       guest_coach  \
# 464         464  Bundesliga  Sa. 04.05.2019       29               NaN
# 465         465  Bundesliga  Sa. 11.05.2019       30      Reiner Geyer
# 466         466  Bundesliga  Sa. 18.05.2019       31               NaN
# 467         467  Bundesliga  Sa. 25.05.2019       32      Reiner Geyer
# 468         468     ÖFB-Cup  Fr. 20.07.2018  1.Runde  Ernst Baumeister
#
#     guest_game_system  guest_team_id           guest_team_name    home_coach  \
# 464               NaN            170             SK Rapid Wien  Reiner Geyer
# 465                 ?            503  FC Admira Wacker Mödling           NaN
# 466               NaN           2444       FC Wacker Innsbruck  Reiner Geyer
# 467    4-3-3 defensiv            503  FC Admira Wacker Mödling           NaN
# 468             4-5-1            503  FC Admira Wacker Mödling           NaN
#
#     home_game_system  home_team_id            home_team_name  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 469 entries, 0 to 468
# Data columns (total 17 columns):
# Unnamed: 0           469 non-null int64
# competition          469 non-null object
# date                 469 non-null object
# gameday              469 non-null object
# guest_coach          244 non-null object
# guest_game_system    244 non-null object
# guest_team_id        469 non-null int64
# guest_team_name      469 non-null object
# home_coach           225 non-null object
# home_game_system     225 non-null object
# home_team_id         469 non-null int64
# home_team_name       469 non-null object
# identifier           469 non-null object
# result               469 non-null object
# saison               469 non-null object
# time                 469 non-null object
# viewers              469 non-null int64
# dtypes: int64(4), object(13)
# memory usage: 62.4+ KB

# %%
df[df.result.str.len() > 3]
# Out:
#      Unnamed: 0 competition            date     gameday       guest_coach  \
# 68           68     ÖFB-Cup  Mi. 26.09.2018     2.Runde               NaN
# 162         162     ÖFB-Cup  Mi. 03.04.2019  Halbfinale               NaN
# 195         195     ÖFB-Cup  Fr. 20.07.2018     1.Runde     Markus Schopp
# 426         426     ÖFB-Cup  Mi. 26.09.2018     2.Runde    Goran Djuricin
# 429         429     ÖFB-Cup  Mi. 03.04.2019  Halbfinale  Dietmar Kühbauer
#
#     guest_game_system  guest_team_id guest_team_name      home_coach  \
# 68                NaN            170   SK Rapid Wien   Klaus Schmidt
# 162               NaN            170   SK Rapid Wien  Oliver Glasner
# 195    4-4-2 doppel 6           4467    TSV Hartberg             NaN
# 426          4-2-3-1             170   SK Rapid Wien             NaN
# 429          4-2-3-1             170   SK Rapid Wien             NaN
#
#     home_game_system  home_team_id  home_team_name  \
# ...

# %%
df.home_coach.value_counts().head()
# Out:
# Marco Rose          24
# Dietmar Kühbauer    22
# Oliver Glasner      20
# Markus Schopp       18
# Christian Ilzer     18
# Name: home_coach, dtype: int64

# %%
df.home_game_system.value_counts()
# Out:
# 3-4-3 flach       33
# 4-2-3-1           31
# 4-4-2 doppel 6    30
# 4-3-1-2           28
# ?                 22
# 5-3-2             21
# 4-3-3 offensiv    10
# 3-5-2              8
# 4-5-1              8
# 4-3-3 defensiv     7
# 4-1-4-1            6
# 4-1-3-2            5
# 5-4-1 flach        5
# 3-5-2 offensiv     3
# 3-4-1-2            2
# 3-5-2 flach        2
# 4-4-2 Raute        2
# 3-4-2-1            1
# 4-3-2-1            1
# Name: home_game_system, dtype: int64

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df['date'] = df['date'].str[4:]
df.head()
# Out:
#   competition        date gameday     guest_coach guest_game_system  \
# 0  Bundesliga  27.07.2018       1  Karl Daxbacher       5-4-1 flach
# 1  Bundesliga  04.08.2018       2             NaN               NaN
# 2  Bundesliga  11.08.2018       3  Karl Daxbacher          4-2-3-1
# 3  Bundesliga  18.08.2018       4             NaN               NaN
# 4  Bundesliga  26.08.2018       5  Karl Daxbacher          4-2-3-1
#
#    guest_team_id      guest_team_name      home_coach home_game_system  \
# 0           2444  FC Wacker Innsbruck             NaN              NaN
# 1            122        SK Sturm Graz  Karl Daxbacher   4-4-2 doppel 6
# 2           2444  FC Wacker Innsbruck             NaN              NaN
# 3           2662       SKN St. Pölten  Karl Daxbacher   4-4-2 doppel 6
# 4           2444  FC Wacker Innsbruck             NaN              NaN
#
#    home_team_id       home_team_name  \
# 0            14      FK Austria Wien
# 1          2444  FC Wacker Innsbruck
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#   competition       date gameday     guest_coach guest_game_system  \
# 0  Bundesliga 2018-07-27       1  Karl Daxbacher       5-4-1 flach
# 1  Bundesliga 2018-04-08       2             NaN               NaN
# 2  Bundesliga 2018-11-08       3  Karl Daxbacher          4-2-3-1
# 3  Bundesliga 2018-08-18       4             NaN               NaN
# 4  Bundesliga 2018-08-26       5  Karl Daxbacher          4-2-3-1
#
#    guest_team_id      guest_team_name      home_coach home_game_system  \
# 0           2444  FC Wacker Innsbruck             NaN              NaN
# 1            122        SK Sturm Graz  Karl Daxbacher   4-4-2 doppel 6
# 2           2444  FC Wacker Innsbruck             NaN              NaN
# 3           2662       SKN St. Pölten  Karl Daxbacher   4-4-2 doppel 6
# 4           2444  FC Wacker Innsbruck             NaN              NaN
#
#    home_team_id       home_team_name  \
# 0            14      FK Austria Wien
# 1          2444  FC Wacker Innsbruck
# ...

# %%
df['weekday'] = df['date'].dt.weekday

# %%
df['day'] = df['date'].dt.day
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

# %%
df.head()
# Out:
#   competition       date gameday     guest_coach guest_game_system  \
# 0  Bundesliga 2018-07-27       1  Karl Daxbacher       5-4-1 flach
# 1  Bundesliga 2018-04-08       2             NaN               NaN
# 2  Bundesliga 2018-11-08       3  Karl Daxbacher          4-2-3-1
# 3  Bundesliga 2018-08-18       4             NaN               NaN
# 4  Bundesliga 2018-08-26       5  Karl Daxbacher          4-2-3-1
#
#    guest_team_id      guest_team_name      home_coach home_game_system  \
# 0           2444  FC Wacker Innsbruck             NaN              NaN
# 1            122        SK Sturm Graz  Karl Daxbacher   4-4-2 doppel 6
# 2           2444  FC Wacker Innsbruck             NaN              NaN
# 3           2662       SKN St. Pölten  Karl Daxbacher   4-4-2 doppel 6
# 4           2444  FC Wacker Innsbruck             NaN              NaN
#
#    home_team_id       home_team_name  \
# 0            14      FK Austria Wien
# 1          2444  FC Wacker Innsbruck
# ...

# %%
df.index = df['date']

# %%
df.head()
# Out:
#            competition       date gameday     guest_coach guest_game_system  \
# date
# 2018-07-27  Bundesliga 2018-07-27       1  Karl Daxbacher       5-4-1 flach
# 2018-04-08  Bundesliga 2018-04-08       2             NaN               NaN
# 2018-11-08  Bundesliga 2018-11-08       3  Karl Daxbacher          4-2-3-1
# 2018-08-18  Bundesliga 2018-08-18       4             NaN               NaN
# 2018-08-26  Bundesliga 2018-08-26       5  Karl Daxbacher          4-2-3-1
#
#             guest_team_id      guest_team_name      home_coach  \
# date
# 2018-07-27           2444  FC Wacker Innsbruck             NaN
# 2018-04-08            122        SK Sturm Graz  Karl Daxbacher
# 2018-11-08           2444  FC Wacker Innsbruck             NaN
# 2018-08-18           2662       SKN St. Pölten  Karl Daxbacher
# 2018-08-26           2444  FC Wacker Innsbruck             NaN
#
#            home_game_system  home_team_id       home_team_name  \
# date
# ...

# %%
df_home_nan = df[df.home_coach.isnull()]
df_guest_nan = df[df.guest_coach.isnull()]

# %%
df_home_nan
# Out:
#                                   competition       date             gameday  \
# date
# 2018-07-27                         Bundesliga 2018-07-27                   1
# 2018-11-08                         Bundesliga 2018-11-08                   3
# 2018-08-26                         Bundesliga 2018-08-26                   5
# 2018-09-16                         Bundesliga 2018-09-16                   7
# 2018-09-30                         Bundesliga 2018-09-30                   9
# 2018-10-20                         Bundesliga 2018-10-20                  11
# 2018-03-11                         Bundesliga 2018-03-11                  13
# 2018-11-25                         Bundesliga 2018-11-25                  15
# 2018-09-12                         Bundesliga 2018-09-12                  17
# 2019-02-23                         Bundesliga 2019-02-23                  19
# 2019-10-03                         Bundesliga 2019-10-03                  21
# ...

# %%
df.shape
# Out:
# (469, 20)

# %%
dictionary_home_coach = {}
    
    
for i in range(len(df_guest_nan.date)):
    dictionary_home_coach[df_guest_nan.identifier[i]] = df_guest_nan.home_coach[i]

# %%
dictionary_home_coach
# Out:
# {'c8db4c597ca5d0abfb449ef80cc75efbffbb9122afbca5ed3c1fe983d4feb952': 'Karl Daxbacher',
#  '7667ba116b5e2e23eafab6f8ec6546d478144f57d9163602f90fa7fc6db3d5a2': 'Karl Daxbacher',
#  'c5bb6bafceb34cad4617cc695841a9541a0f3672579e55b9729cd1bd0e48d531': 'Karl Daxbacher',
#  '58fbdf6ecaafa80fb900e07836279e70287e40da91ff38840cf4f1e6bf26fdc8': 'Karl Daxbacher',
#  '870a12f009eae1e62ec43615cd538b2b492b968276202e180eb1e9d51eaf7ac9': 'Karl Daxbacher',
#  '1cdf1ecf08142163defb9480f827d9013de045a36f13ebac83d492621a8e348e': 'Karl Daxbacher',
#  'b3fc83ee9a80a64d85cde069da82237ab2257dd37f658623411dc978ef5a8963': 'Karl Daxbacher',
#  '8a1e08f8f5436dcffb4c8d00e6c295a855c9fd1477204ba2dfeb919058498b03': 'Karl Daxbacher',
#  '258c85559052f1252da81872d903e81993935c8f63ea6724488388c2b54212fe': 'Karl Daxbacher',
#  '6e0f06187de0aa67690f259e56f0cdbb14511b834633f9e7050d18909b620ab6': 'Karl Daxbacher',
#  'aee09eccb3f16115ddf29ea3b7faf3147f5e7aaeff83aa1244722957bc51e940': 'Thomas Grumser',
# ...

# %%
'guest_game_system': df_guest_nan.home_game_system[i]
map_list.append(dictionary)

map_list

# %%
df_guest_nan.guest_coach.head()
# Out:
# date
# 2018-04-08    NaN
# 2018-08-18    NaN
# 2018-01-09    NaN
# 2018-09-23    NaN
# 2018-07-10    NaN
# Name: guest_coach, dtype: object

# %%
df_home_nan.home_coach = df_home_nan.identifier.map(dictionary_home_coach)

# %%
df_home_nan.head()
# Out:
#            competition       date gameday     guest_coach guest_game_system  \
# date
# 2018-07-27  Bundesliga 2018-07-27       1  Karl Daxbacher       5-4-1 flach
# 2018-11-08  Bundesliga 2018-11-08       3  Karl Daxbacher          4-2-3-1
# 2018-08-26  Bundesliga 2018-08-26       5  Karl Daxbacher          4-2-3-1
# 2018-09-16  Bundesliga 2018-09-16       7  Karl Daxbacher          4-2-3-1
# 2018-09-30  Bundesliga 2018-09-30       9  Karl Daxbacher          4-2-3-1
#
#             guest_team_id      guest_team_name       home_coach  \
# date
# 2018-07-27           2444  FC Wacker Innsbruck    Thomas Letsch
# 2018-11-08           2444  FC Wacker Innsbruck  Werner Grabherr
# 2018-08-26           2444  FC Wacker Innsbruck   Goran Djuricin
# 2018-09-16           2444  FC Wacker Innsbruck  Christian Ilzer
# 2018-09-30           2444  FC Wacker Innsbruck    Klaus Schmidt
#
#            home_game_system  home_team_id       home_team_name  \
# date
# ...

# %%
df_home_nan.shape
# Out:
# (244, 20)

# %%
df.shape
# Out:
# (469, 20)
