# %%
import numpy as np
import pandas as pd
import json

# %%
file_name = 'bundesliga-2009-2018'

# %%
df = pd.read_csv(file_name + '.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 competition            date gameday     guest_coach  \
# 0           0  Bundesliga  Sa. 18.07.2009       1  Paul Gludovatz
# 1           1  Bundesliga  Sa. 25.07.2009       2             NaN
# 2           2  Bundesliga  Fr. 31.07.2009       3  Paul Gludovatz
# 3           3  Bundesliga  So. 09.08.2009       4             NaN
# 4           4  Bundesliga  Fr. 21.08.2009       5  Paul Gludovatz
#
#   guest_game_system  guest_team_id    guest_team_name      home_coach  \
# 0             5-4-1            266            SV Ried             NaN
# 1               NaN            409  Red Bull Salzburg  Paul Gludovatz
# 2             5-4-1            266            SV Ried             NaN
# 3               NaN            170      SK Rapid Wien  Paul Gludovatz
# 4           3-4-2-1            266            SV Ried             NaN
#
#   home_game_system  home_team_id      home_team_name  \
# 0              NaN          2394       SV Kapfenberg
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0 competition            date       gameday      guest_coach  \
# 4380        4380  Bundesliga  So. 19.05.2019            31  Christian Ilzer
# 4381        4381  Bundesliga  So. 26.05.2019            32              NaN
# 4382        4382     ÖFB-Cup  Sa. 21.07.2018       1.Runde  Christian Ilzer
# 4383        4383     ÖFB-Cup  Di. 25.09.2018       2.Runde              NaN
# 4384        4384     ÖFB-Cup  Mi. 31.10.2018  Achtelfinale              NaN
#
#      guest_game_system  guest_team_id        guest_team_name       home_coach  \
# 4380    4-4-2 doppel 6           4441         Wolfsberger AC              NaN
# 4381               NaN            122          SK Sturm Graz  Christian Ilzer
# 4382    4-4-2 doppel 6           4441         Wolfsberger AC              NaN
# 4383               NaN          28760  SK Austria Klagenfurt  Christian Ilzer
# 4384               NaN            170          SK Rapid Wien  Christian Ilzer
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4385 entries, 0 to 4384
# Data columns (total 17 columns):
# Unnamed: 0           4385 non-null int64
# competition          4385 non-null object
# date                 4385 non-null object
# gameday              4385 non-null object
# guest_coach          2284 non-null object
# guest_game_system    2284 non-null object
# guest_team_id        4385 non-null int64
# guest_team_name      4385 non-null object
# home_coach           2101 non-null object
# home_game_system     2101 non-null object
# home_team_id         4385 non-null int64
# home_team_name       4385 non-null object
# identifier           4385 non-null object
# result               4385 non-null object
# saison               4385 non-null object
# time                 4385 non-null object
# viewers              4385 non-null int64
# dtypes: int64(4), object(13)
# memory usage: 582.5+ KB

# %%
df[df.result.str.len() > 3]
# Out:
#       Unnamed: 0                          competition            date  \
# 39            39                              ÖFB-Cup  Mi. 31.03.2010
# 89            89                              ÖFB-Cup  Sa. 15.08.2009
# 92            92                              ÖFB-Cup  Di. 30.03.2010
# 171          171                              ÖFB-Cup  Mi. 31.03.2010
# 181          181          Europa League Qualifikation  Do. 27.08.2009
# 258          258                              ÖFB-Cup  Fr. 18.09.2009
# 260          260                              ÖFB-Cup  Mi. 31.03.2010
# 309          309          Europa League Qualifikation  Do. 06.08.2009
# 348          348                              ÖFB-Cup  Sa. 15.08.2009
# 530          530                              ÖFB-Cup  Mi. 10.11.2010
# 655          655                              ÖFB-Cup  Mi. 10.11.2010
# 732          732                              ÖFB-Cup  Di. 09.11.2010
# ...

# %%
df.home_coach.value_counts().head()
# Out:
# Franco Foda            132
# Dietmar Kühbauer       112
# Peter Schöttel          86
# Heimo Pfeifenberger     86
# Karl Daxbacher          78
# Name: home_coach, dtype: int64

# %%
df.home_game_system.value_counts()
# Out:
# 4-2-3-1           619
# 4-4-2 doppel 6    315
# 4-4-2             194
# 4-1-4-1           175
# 4-4-2 Raute       118
# 4-3-3 offensiv    102
# 4-5-1             100
# 4-3-3 defensiv     83
# 3-4-3 flach        71
# 3-3-3-1            53
# 4-3-1-2            41
# ?                  39
# 5-4-1              27
# 5-3-2              27
# 5-4-1 flach        19
# 4-1-3-2            19
# 3-1-4-2            17
# 3-5-2 flach        17
# 4-4-1-1            16
# 3-5-2              15
# 3-4-2-1            10
# 3-4-1-2             8
# 3-5-2 offensiv      6
# 4-3-2-1             5
# 4-5-1 flach         4
# 3-4-3               1
# Name: home_game_system, dtype: int64

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df[df.viewers == 11422]
# Out:
#     competition            date gameday      guest_coach guest_game_system  \
# 134  Bundesliga  Sa. 01.08.2009       3  Matthias Hamann             4-4-2
# 409  Bundesliga  Sa. 01.08.2009       3              NaN               NaN
#
#      guest_team_id guest_team_name    home_coach home_game_system  \
# 134            413            LASK           NaN              NaN
# 409            413            LASK  Huub Stevens            4-5-1
#
#      home_team_id     home_team_name  \
# 134           409  Red Bull Salzburg
# 409           409  Red Bull Salzburg
#
#                                             identifier result   saison   time  \
# 134  a2972fa1a656af76374517bb92fe5e42cd5306841e247e...    3:2  2009/10  19:30
# 409  a2972fa1a656af76374517bb92fe5e42cd5306841e247e...    3:2  2009/10  19:30
#
#      viewers
# 134    11422
# 409    11422

# %%
df['date'] = df['date'].str[4:]
df.head()
# Out:
#   competition        date gameday     guest_coach guest_game_system  \
# 0  Bundesliga  18.07.2009       1  Paul Gludovatz             5-4-1
# 1  Bundesliga  25.07.2009       2             NaN               NaN
# 2  Bundesliga  31.07.2009       3  Paul Gludovatz             5-4-1
# 3  Bundesliga  09.08.2009       4             NaN               NaN
# 4  Bundesliga  21.08.2009       5  Paul Gludovatz           3-4-2-1
#
#    guest_team_id    guest_team_name      home_coach home_game_system  \
# 0            266            SV Ried             NaN              NaN
# 1            409  Red Bull Salzburg  Paul Gludovatz            5-4-1
# 2            266            SV Ried             NaN              NaN
# 3            170      SK Rapid Wien  Paul Gludovatz            5-4-1
# 4            266            SV Ried             NaN              NaN
#
#    home_team_id      home_team_name  \
# 0          2394       SV Kapfenberg
# 1           266             SV Ried
# ...

# %%
df[df.viewers == 11422]
# Out:
#     competition        date gameday      guest_coach guest_game_system  \
# 134  Bundesliga  01.08.2009       3  Matthias Hamann             4-4-2
# 409  Bundesliga  01.08.2009       3              NaN               NaN
#
#      guest_team_id guest_team_name    home_coach home_game_system  \
# 134            413            LASK           NaN              NaN
# 409            413            LASK  Huub Stevens            4-5-1
#
#      home_team_id     home_team_name  \
# 134           409  Red Bull Salzburg
# 409           409  Red Bull Salzburg
#
#                                             identifier result   saison   time  \
# 134  a2972fa1a656af76374517bb92fe5e42cd5306841e247e...    3:2  2009/10  19:30
# 409  a2972fa1a656af76374517bb92fe5e42cd5306841e247e...    3:2  2009/10  19:30
#
#      viewers
# 134    11422
# 409    11422

# %%
df['date'] = df['date'] + ' ' + df['time']
df['date'] = pd.to_datetime(df['date'], dayfirst=True)

# %%
df[df.viewers == 11422]
# Out:
#     competition                date gameday      guest_coach  \
# 134  Bundesliga 2009-08-01 19:30:00       3  Matthias Hamann
# 409  Bundesliga 2009-08-01 19:30:00       3              NaN
#
#     guest_game_system  guest_team_id guest_team_name    home_coach  \
# 134             4-4-2            413            LASK           NaN
# 409               NaN            413            LASK  Huub Stevens
#
#     home_game_system  home_team_id     home_team_name  \
# 134              NaN           409  Red Bull Salzburg
# 409            4-5-1           409  Red Bull Salzburg
#
#                                             identifier result   saison   time  \
# 134  a2972fa1a656af76374517bb92fe5e42cd5306841e247e...    3:2  2009/10  19:30
# 409  a2972fa1a656af76374517bb92fe5e42cd5306841e247e...    3:2  2009/10  19:30
#
#      viewers
# 134    11422
# 409    11422

# %%
df.head()
# Out:
#   competition                date gameday     guest_coach guest_game_system  \
# 0  Bundesliga 2009-07-18 19:30:00       1  Paul Gludovatz             5-4-1
# 1  Bundesliga 2009-07-25 19:30:00       2             NaN               NaN
# 2  Bundesliga 2009-07-31 20:30:00       3  Paul Gludovatz             5-4-1
# 3  Bundesliga 2009-08-09 19:30:00       4             NaN               NaN
# 4  Bundesliga 2009-08-21 20:30:00       5  Paul Gludovatz           3-4-2-1
#
#    guest_team_id    guest_team_name      home_coach home_game_system  \
# 0            266            SV Ried             NaN              NaN
# 1            409  Red Bull Salzburg  Paul Gludovatz            5-4-1
# 2            266            SV Ried             NaN              NaN
# 3            170      SK Rapid Wien  Paul Gludovatz            5-4-1
# 4            266            SV Ried             NaN              NaN
#
#    home_team_id      home_team_name  \
# 0          2394       SV Kapfenberg
# ...

# %%
df['weekday'] = df['date'].dt.weekday

# %%
df['day'] = df['date'].dt.day
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

# %%
df.head()
# Out:
#   competition                date gameday     guest_coach guest_game_system  \
# 0  Bundesliga 2009-07-18 19:30:00       1  Paul Gludovatz             5-4-1
# 1  Bundesliga 2009-07-25 19:30:00       2             NaN               NaN
# 2  Bundesliga 2009-07-31 20:30:00       3  Paul Gludovatz             5-4-1
# 3  Bundesliga 2009-08-09 19:30:00       4             NaN               NaN
# 4  Bundesliga 2009-08-21 20:30:00       5  Paul Gludovatz           3-4-2-1
#
#    guest_team_id    guest_team_name      home_coach home_game_system  \
# 0            266            SV Ried             NaN              NaN
# 1            409  Red Bull Salzburg  Paul Gludovatz            5-4-1
# 2            266            SV Ried             NaN              NaN
# 3            170      SK Rapid Wien  Paul Gludovatz            5-4-1
# 4            266            SV Ried             NaN              NaN
#
#    home_team_id      home_team_name  \
# 0          2394       SV Kapfenberg
# ...

# %%
df.head()
# Out:
#   competition                date gameday     guest_coach guest_game_system  \
# 0  Bundesliga 2009-07-18 19:30:00       1  Paul Gludovatz             5-4-1
# 1  Bundesliga 2009-07-25 19:30:00       2             NaN               NaN
# 2  Bundesliga 2009-07-31 20:30:00       3  Paul Gludovatz             5-4-1
# 3  Bundesliga 2009-08-09 19:30:00       4             NaN               NaN
# 4  Bundesliga 2009-08-21 20:30:00       5  Paul Gludovatz           3-4-2-1
#
#    guest_team_id    guest_team_name      home_coach home_game_system  \
# 0            266            SV Ried             NaN              NaN
# 1            409  Red Bull Salzburg  Paul Gludovatz            5-4-1
# 2            266            SV Ried             NaN              NaN
# 3            170      SK Rapid Wien  Paul Gludovatz            5-4-1
# 4            266            SV Ried             NaN              NaN
#
#    home_team_id      home_team_name  \
# 0          2394       SV Kapfenberg
# ...

# %%
dictionary_home_coach = {}
for i in range(len(df.date)):
    if type(df.home_coach[i]) == str:
        dictionary_home_coach[df.identifier[i]] = df.home_coach[i]

        
dictionary_guest_coach = {}
for i in range(len(df.date)):
    if type(df.guest_coach[i]) == str:
        dictionary_guest_coach[df.identifier[i]] = df.guest_coach[i]

        
dictionary_home_game_system = {}
for i in range(len(df.date)):
    if type(df.home_game_system[i]) == str:
        dictionary_home_game_system[df.identifier[i]] = df.home_game_system[i]


dictionary_guest_game_system = {}
for i in range(len(df.date)):
    if type(df.guest_game_system[i]) == str:
        dictionary_guest_game_system[df.identifier[i]] = df.guest_game_system[i]

# %%
df.home_coach = df.identifier.map(dictionary_home_coach)
df.guest_coach = df.identifier.map(dictionary_guest_coach)
df.home_game_system = df.identifier.map(dictionary_home_game_system)
df.guest_game_system = df.identifier.map(dictionary_guest_game_system)

# %%
df.shape
# Out:
# (4385, 20)

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2509 entries, 0 to 4383
# Data columns (total 20 columns):
# competition          2509 non-null object
# date                 2509 non-null datetime64[ns]
# gameday              2509 non-null object
# guest_coach          2284 non-null object
# guest_game_system    2284 non-null object
# guest_team_id        2509 non-null int64
# guest_team_name      2509 non-null object
# home_coach           2101 non-null object
# home_game_system     2101 non-null object
# home_team_id         2509 non-null int64
# home_team_name       2509 non-null object
# identifier           2509 non-null object
# result               2509 non-null object
# saison               2509 non-null object
# time                 2509 non-null object
# viewers              2509 non-null int64
# weekday              2509 non-null int64
# day                  2509 non-null int64
# month                2509 non-null int64
# year                 2509 non-null int64
# ...

# %%
df.head()
# Out:
#   competition                date gameday     guest_coach guest_game_system  \
# 0  Bundesliga 2009-07-18 19:30:00       1  Paul Gludovatz             5-4-1
# 1  Bundesliga 2009-07-25 19:30:00       2    Huub Stevens       4-4-2 Raute
# 2  Bundesliga 2009-07-31 20:30:00       3  Paul Gludovatz             5-4-1
# 3  Bundesliga 2009-08-09 19:30:00       4    Peter Pacult    4-4-2 doppel 6
# 4  Bundesliga 2009-08-21 20:30:00       5  Paul Gludovatz           3-4-2-1
#
#    guest_team_id    guest_team_name          home_coach home_game_system  \
# 0            266            SV Ried  Werner Gregoritsch            4-5-1
# 1            409  Red Bull Salzburg      Paul Gludovatz            5-4-1
# 2            266            SV Ried        Helmut Kraft            4-4-2
# 3            170      SK Rapid Wien      Paul Gludovatz            5-4-1
# 4            266            SV Ried   Frenkie Schinkels            4-5-1
#
#    home_team_id      home_team_name  \
# ...

# %%
df.to_csv(file_name + '_clean.csv')
