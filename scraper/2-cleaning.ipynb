# %%
import numpy as np
import pandas as pd
import json

# %%
file_name = 'zweite-liga-2009-2018'
df_2009_2018 = pd.read_csv(file_name + '.csv', index_col=0)

# %%
file_name = 'zweite-liga-2019'
df_2019 = pd.read_csv(file_name + '.csv', index_col=0)

# %%
df = pd.concat([df_2009_2018, df_2019], ignore_index=True)
# df.reset_index()

# %%
df.head()
# Out:
#   competition            date gameday      guest_coach guest_game_system  \
# 0     2. Liga  Di. 14.07.2009       1              NaN               NaN
# 1     2. Liga  Fr. 17.07.2009       2  Michael Fuchs †             4-5-1
# 2     2. Liga  Fr. 24.07.2009       3              NaN               NaN
# 3     2. Liga  Fr. 31.07.2009       4  Michael Fuchs †    4-3-3 defensiv
# 4     2. Liga  Sa. 08.08.2009       5              NaN               NaN
#
#    guest_team_id      guest_team_name       home_coach home_game_system  \
# 0           2364      First Vienna FC  Michael Fuchs †            4-4-2
# 1           5192          FC Gratkorn              NaN              NaN
# 2           4467         TSV Hartberg  Michael Fuchs †      4-4-2 Raute
# 3           5192          FC Gratkorn              NaN              NaN
# 4           3551  SC Rheindorf Altach  Michael Fuchs †            4-4-2
#
#    home_team_id             home_team_name  \
# 0          5192                FC Gratkorn
# 1          6227  Red Bull Juniors Salzburg
# 2          5192                FC Gratkorn
# 3           541        SC Austria Lustenau
# 4          5192                FC Gratkorn
#
#                                           identifier result   saison   time  \
# 0  4c0f0ae86edebb6bcc1ad9c5d833e0055eea9911b86e5a...    1:1  2009/10  19:00
# 1  23c2ed48d6acf618f5a985662d4841d3eca5ac6a93327b...    3:3  2009/10  18:00
# 2  54806304f66469bdc7b58fe72f800df0eb416eb74249df...    0:0  2009/10  18:00
# 3  34194b3d3200c826828639f67b15c0bfb85696bb2a9f4a...    2:1  2009/10  18:00
# 4  63ec3baaf729fdf854bc02ed1c0d83b7c4de76bd5c5af0...    3:1  2009/10  17:00
#
#    viewers
# 0     1000
# 1      200
# 2     1200
# 3     2600
# 4     1100

# %%
df.tail()
# Out:
#      competition            date  gameday         guest_coach  \
# 4603     2. Liga  Fr. 02.08.2019        2  Gerald Baumgartner
# 4604     2. Liga  So. 11.08.2019        3                 NaN
# 4605     2. Liga  Fr. 16.08.2019        4  Gerald Baumgartner
# 4606     ÖFB-Cup  Fr. 19.07.2019  1.Runde  Gerald Baumgartner
# 4607     ÖFB-Cup  Di. 24.09.2019  2.Runde                 NaN
#
#      guest_game_system  guest_team_id guest_team_name          home_coach  \
# 4603           3-4-1-2            266         SV Ried                 NaN
# 4604               NaN          12210   SKU Amstetten  Gerald Baumgartner
# 4605          4-2-3-1             266         SV Ried                 NaN
# 4606          4-2-3-1             266         SV Ried                 NaN
# 4607               NaN            266         SV Ried                 NaN
#
#      home_game_system  home_team_id        home_team_name  \
# 4603              NaN           541   SC Austria Lustenau
# 4604          3-4-1-2           266               SV Ried
# 4605              NaN         19536            SV Lafnitz
# 4606              NaN         14601  ASK-BSC Bruck/Leitha
# 4607              NaN          1521     SK Vorwärts Steyr
#
#                                              identifier result   saison  \
# 4603  4e87e70c040386220ac0ba0f6fbceb6de5a18818a8ae51...    1:1  2019/20
# 4604  02dd4337df8f560646bdfa7160069119c2123153eab950...    4:1  2019/20
# 4605  12ad3a2962d7da019db899e3afa47b15b18ab54f2b0174...    0:1  2019/20
# 4606  85480403576d2c329c8a3faf5ab7988f5aceafd98426e9...    0:4  2019/20
# 4607  4149159aae902ba7b0d007842b51e7a45d065da636f2d9...    -:-  2019/20
#
#        time  viewers
# 4603  19:10     3200
# 4604  10:30     2915
# 4605  19:10      810
# 4606  18:30      450
# 4607      -        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4608 entries, 0 to 4607
# Data columns (total 16 columns):
# competition          4608 non-null object
# date                 4608 non-null object
# gameday              4608 non-null object
# guest_coach          2370 non-null object
# guest_game_system    2367 non-null object
# guest_team_id        4608 non-null int64
# guest_team_name      4608 non-null object
# home_coach           2179 non-null object
# home_game_system     2175 non-null object
# home_team_id         4608 non-null int64
# home_team_name       4608 non-null object
# identifier           4608 non-null object
# result               4608 non-null object
# saison               4608 non-null object
# time                 4608 non-null object
# viewers              4608 non-null int64
# dtypes: int64(3), object(13)
# memory usage: 576.1+ KB

# %%
df = df[df.result != '-:-']

# %%
df = df.reset_index()
df = df.drop('index', axis=1)

# %%
df.tail()
# Out:
#      competition            date  gameday         guest_coach  \
# 4544     2. Liga  Fr. 26.07.2019        1                 NaN
# 4545     2. Liga  Fr. 02.08.2019        2  Gerald Baumgartner
# 4546     2. Liga  So. 11.08.2019        3                 NaN
# 4547     2. Liga  Fr. 16.08.2019        4  Gerald Baumgartner
# 4548     ÖFB-Cup  Fr. 19.07.2019  1.Runde  Gerald Baumgartner
#
#      guest_game_system  guest_team_id        guest_team_name  \
# 4544               NaN          28760  SK Austria Klagenfurt
# 4545           3-4-1-2            266                SV Ried
# 4546               NaN          12210          SKU Amstetten
# 4547          4-2-3-1             266                SV Ried
# 4548          4-2-3-1             266                SV Ried
#
#               home_coach home_game_system  home_team_id        home_team_name  \
# 4544  Gerald Baumgartner         4-2-3-1            266               SV Ried
# 4545                 NaN              NaN           541   SC Austria Lustenau
# 4546  Gerald Baumgartner          3-4-1-2           266               SV Ried
# 4547                 NaN              NaN         19536            SV Lafnitz
# 4548                 NaN              NaN         14601  ASK-BSC Bruck/Leitha
#
#                                              identifier result   saison  \
# 4544  3799970ce738e75be4b261ef10dcb6457655e3107ed797...    1:3  2019/20
# 4545  4e87e70c040386220ac0ba0f6fbceb6de5a18818a8ae51...    1:1  2019/20
# 4546  02dd4337df8f560646bdfa7160069119c2123153eab950...    4:1  2019/20
# 4547  12ad3a2962d7da019db899e3afa47b15b18ab54f2b0174...    0:1  2019/20
# 4548  85480403576d2c329c8a3faf5ab7988f5aceafd98426e9...    0:4  2019/20
#
#        time  viewers
# 4544  19:10     2667
# 4545  19:10     3200
# 4546  10:30     2915
# 4547  19:10      810
# 4548  18:30      450

# %%
df.home_coach.value_counts().head()
# Out:
# Karl Daxbacher          93
# Martin Scherb           76
# Kurt Russ               74
# Bruno Friesenbichler    70
# Adi Hütter              67
# Name: home_coach, dtype: int64

# %%
df.home_game_system.value_counts()
# Out:
# 4-2-3-1           518
# 4-4-2             381
# 4-4-2 doppel 6    254
# 4-1-4-1           235
# ?                 166
# 4-3-3 offensiv    142
# 4-4-2 Raute        93
# 4-5-1              91
# 4-4-1-1            73
# 3-4-3 flach        55
# 4-3-3 defensiv     43
# 3-5-2              37
# 3-4-1-2            14
# 5-4-1 flach        13
# 4-1-3-2            12
# 4-3-1-2             9
# 3-1-4-2             8
# 3-3-3-1             7
# 3-5-2 flach         6
# 3-5-2 offensiv      6
# 4-3-2-1             4
# 3-4-2-1             3
# 5-3-2               2
# 4-5-1 flach         2
# 5-4-1               1
# Name: home_game_system, dtype: int64

# %%
# df = df.drop('Unnamed: 0', axis=1)

# %%
df[df.viewers == 11422]
# Out:
# Empty DataFrame
# Columns: [competition, date, gameday, guest_coach, guest_game_system, guest_team_id, guest_team_name, home_coach, home_game_system, home_team_id, home_team_name, identifier, result, saison, time, viewers]
# Index: []

# %%
df['date'] = df['date'].str[4:]
df.head()
# Out:
#   competition        date gameday      guest_coach guest_game_system  \
# 0     2. Liga  14.07.2009       1              NaN               NaN
# 1     2. Liga  17.07.2009       2  Michael Fuchs †             4-5-1
# 2     2. Liga  24.07.2009       3              NaN               NaN
# 3     2. Liga  31.07.2009       4  Michael Fuchs †    4-3-3 defensiv
# 4     2. Liga  08.08.2009       5              NaN               NaN
#
#    guest_team_id      guest_team_name       home_coach home_game_system  \
# 0           2364      First Vienna FC  Michael Fuchs †            4-4-2
# 1           5192          FC Gratkorn              NaN              NaN
# 2           4467         TSV Hartberg  Michael Fuchs †      4-4-2 Raute
# 3           5192          FC Gratkorn              NaN              NaN
# 4           3551  SC Rheindorf Altach  Michael Fuchs †            4-4-2
#
#    home_team_id             home_team_name  \
# 0          5192                FC Gratkorn
# 1          6227  Red Bull Juniors Salzburg
# 2          5192                FC Gratkorn
# 3           541        SC Austria Lustenau
# 4          5192                FC Gratkorn
#
#                                           identifier result   saison   time  \
# 0  4c0f0ae86edebb6bcc1ad9c5d833e0055eea9911b86e5a...    1:1  2009/10  19:00
# 1  23c2ed48d6acf618f5a985662d4841d3eca5ac6a93327b...    3:3  2009/10  18:00
# 2  54806304f66469bdc7b58fe72f800df0eb416eb74249df...    0:0  2009/10  18:00
# 3  34194b3d3200c826828639f67b15c0bfb85696bb2a9f4a...    2:1  2009/10  18:00
# 4  63ec3baaf729fdf854bc02ed1c0d83b7c4de76bd5c5af0...    3:1  2009/10  17:00
#
#    viewers
# 0     1000
# 1      200
# 2     1200
# 3     2600
# 4     1100

# %%
df[df.viewers == 11422]
# Out:
# Empty DataFrame
# Columns: [competition, date, gameday, guest_coach, guest_game_system, guest_team_id, guest_team_name, home_coach, home_game_system, home_team_id, home_team_name, identifier, result, saison, time, viewers]
# Index: []

# %%
df['date'] = df['date'] + ' ' + df['time']
df['date'] = pd.to_datetime(df['date'], dayfirst=True)

# %%
df[df.viewers == 11422]
# Out:
# Empty DataFrame
# Columns: [competition, date, gameday, guest_coach, guest_game_system, guest_team_id, guest_team_name, home_coach, home_game_system, home_team_id, home_team_name, identifier, result, saison, time, viewers]
# Index: []

# %%
df.tail()
# Out:
#      competition                date  gameday         guest_coach  \
# 4544     2. Liga 2019-07-26 19:10:00        1                 NaN
# 4545     2. Liga 2019-08-02 19:10:00        2  Gerald Baumgartner
# 4546     2. Liga 2019-08-11 10:30:00        3                 NaN
# 4547     2. Liga 2019-08-16 19:10:00        4  Gerald Baumgartner
# 4548     ÖFB-Cup 2019-07-19 18:30:00  1.Runde  Gerald Baumgartner
#
#      guest_game_system  guest_team_id        guest_team_name  \
# 4544               NaN          28760  SK Austria Klagenfurt
# 4545           3-4-1-2            266                SV Ried
# 4546               NaN          12210          SKU Amstetten
# 4547          4-2-3-1             266                SV Ried
# 4548          4-2-3-1             266                SV Ried
#
#               home_coach home_game_system  home_team_id        home_team_name  \
# 4544  Gerald Baumgartner         4-2-3-1            266               SV Ried
# 4545                 NaN              NaN           541   SC Austria Lustenau
# 4546  Gerald Baumgartner          3-4-1-2           266               SV Ried
# 4547                 NaN              NaN         19536            SV Lafnitz
# 4548                 NaN              NaN         14601  ASK-BSC Bruck/Leitha
#
#                                              identifier result   saison  \
# 4544  3799970ce738e75be4b261ef10dcb6457655e3107ed797...    1:3  2019/20
# 4545  4e87e70c040386220ac0ba0f6fbceb6de5a18818a8ae51...    1:1  2019/20
# 4546  02dd4337df8f560646bdfa7160069119c2123153eab950...    4:1  2019/20
# 4547  12ad3a2962d7da019db899e3afa47b15b18ab54f2b0174...    0:1  2019/20
# 4548  85480403576d2c329c8a3faf5ab7988f5aceafd98426e9...    0:4  2019/20
#
#        time  viewers
# 4544  19:10     2667
# 4545  19:10     3200
# 4546  10:30     2915
# 4547  19:10      810
# 4548  18:30      450

# %%
df['weekday'] = df['date'].dt.weekday

# %%
df['day'] = df['date'].dt.day
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

# %%
df.head()
# Out:
#   competition                date gameday      guest_coach guest_game_system  \
# 0     2. Liga 2009-07-14 19:00:00       1              NaN               NaN
# 1     2. Liga 2009-07-17 18:00:00       2  Michael Fuchs †             4-5-1
# 2     2. Liga 2009-07-24 18:00:00       3              NaN               NaN
# 3     2. Liga 2009-07-31 18:00:00       4  Michael Fuchs †    4-3-3 defensiv
# 4     2. Liga 2009-08-08 17:00:00       5              NaN               NaN
#
#    guest_team_id      guest_team_name       home_coach home_game_system  \
# 0           2364      First Vienna FC  Michael Fuchs †            4-4-2
# 1           5192          FC Gratkorn              NaN              NaN
# 2           4467         TSV Hartberg  Michael Fuchs †      4-4-2 Raute
# 3           5192          FC Gratkorn              NaN              NaN
# 4           3551  SC Rheindorf Altach  Michael Fuchs †            4-4-2
#
#    home_team_id             home_team_name  \
# 0          5192                FC Gratkorn
# 1          6227  Red Bull Juniors Salzburg
# 2          5192                FC Gratkorn
# 3           541        SC Austria Lustenau
# 4          5192                FC Gratkorn
#
#                                           identifier result   saison   time  \
# 0  4c0f0ae86edebb6bcc1ad9c5d833e0055eea9911b86e5a...    1:1  2009/10  19:00
# 1  23c2ed48d6acf618f5a985662d4841d3eca5ac6a93327b...    3:3  2009/10  18:00
# 2  54806304f66469bdc7b58fe72f800df0eb416eb74249df...    0:0  2009/10  18:00
# 3  34194b3d3200c826828639f67b15c0bfb85696bb2a9f4a...    2:1  2009/10  18:00
# 4  63ec3baaf729fdf854bc02ed1c0d83b7c4de76bd5c5af0...    3:1  2009/10  17:00
#
#    viewers  weekday  day  month  year
# 0     1000        1   14      7  2009
# 1      200        4   17      7  2009
# 2     1200        4   24      7  2009
# 3     2600        4   31      7  2009
# 4     1100        5    8      8  2009

# %%
df.head()
# Out:
#   competition                date gameday      guest_coach guest_game_system  \
# 0     2. Liga 2009-07-14 19:00:00       1              NaN               NaN
# 1     2. Liga 2009-07-17 18:00:00       2  Michael Fuchs †             4-5-1
# 2     2. Liga 2009-07-24 18:00:00       3              NaN               NaN
# 3     2. Liga 2009-07-31 18:00:00       4  Michael Fuchs †    4-3-3 defensiv
# 4     2. Liga 2009-08-08 17:00:00       5              NaN               NaN
#
#    guest_team_id      guest_team_name       home_coach home_game_system  \
# 0           2364      First Vienna FC  Michael Fuchs †            4-4-2
# 1           5192          FC Gratkorn              NaN              NaN
# 2           4467         TSV Hartberg  Michael Fuchs †      4-4-2 Raute
# 3           5192          FC Gratkorn              NaN              NaN
# 4           3551  SC Rheindorf Altach  Michael Fuchs †            4-4-2
#
#    home_team_id             home_team_name  \
# 0          5192                FC Gratkorn
# 1          6227  Red Bull Juniors Salzburg
# 2          5192                FC Gratkorn
# 3           541        SC Austria Lustenau
# 4          5192                FC Gratkorn
#
#                                           identifier result   saison   time  \
# 0  4c0f0ae86edebb6bcc1ad9c5d833e0055eea9911b86e5a...    1:1  2009/10  19:00
# 1  23c2ed48d6acf618f5a985662d4841d3eca5ac6a93327b...    3:3  2009/10  18:00
# 2  54806304f66469bdc7b58fe72f800df0eb416eb74249df...    0:0  2009/10  18:00
# 3  34194b3d3200c826828639f67b15c0bfb85696bb2a9f4a...    2:1  2009/10  18:00
# 4  63ec3baaf729fdf854bc02ed1c0d83b7c4de76bd5c5af0...    3:1  2009/10  17:00
#
#    viewers  weekday  day  month  year
# 0     1000        1   14      7  2009
# 1      200        4   17      7  2009
# 2     1200        4   24      7  2009
# 3     2600        4   31      7  2009
# 4     1100        5    8      8  2009

# %%
df.head()
# Out:
#   competition                date gameday      guest_coach guest_game_system  \
# 0     2. Liga 2009-07-14 19:00:00       1              NaN               NaN
# 1     2. Liga 2009-07-17 18:00:00       2  Michael Fuchs †             4-5-1
# 2     2. Liga 2009-07-24 18:00:00       3              NaN               NaN
# 3     2. Liga 2009-07-31 18:00:00       4  Michael Fuchs †    4-3-3 defensiv
# 4     2. Liga 2009-08-08 17:00:00       5              NaN               NaN
#
#    guest_team_id      guest_team_name       home_coach home_game_system  \
# 0           2364      First Vienna FC  Michael Fuchs †            4-4-2
# 1           5192          FC Gratkorn              NaN              NaN
# 2           4467         TSV Hartberg  Michael Fuchs †      4-4-2 Raute
# 3           5192          FC Gratkorn              NaN              NaN
# 4           3551  SC Rheindorf Altach  Michael Fuchs †            4-4-2
#
#    home_team_id             home_team_name  \
# 0          5192                FC Gratkorn
# 1          6227  Red Bull Juniors Salzburg
# 2          5192                FC Gratkorn
# 3           541        SC Austria Lustenau
# 4          5192                FC Gratkorn
#
#                                           identifier result   saison   time  \
# 0  4c0f0ae86edebb6bcc1ad9c5d833e0055eea9911b86e5a...    1:1  2009/10  19:00
# 1  23c2ed48d6acf618f5a985662d4841d3eca5ac6a93327b...    3:3  2009/10  18:00
# 2  54806304f66469bdc7b58fe72f800df0eb416eb74249df...    0:0  2009/10  18:00
# 3  34194b3d3200c826828639f67b15c0bfb85696bb2a9f4a...    2:1  2009/10  18:00
# 4  63ec3baaf729fdf854bc02ed1c0d83b7c4de76bd5c5af0...    3:1  2009/10  17:00
#
#    viewers  weekday  day  month  year
# 0     1000        1   14      7  2009
# 1      200        4   17      7  2009
# 2     1200        4   24      7  2009
# 3     2600        4   31      7  2009
# 4     1100        5    8      8  2009

# %%
df.home_coach[1]
# Out:
# nan

# %%
dictionary_home_coach = {}
for i in range(len(df.competition)):
    if type(df.home_coach[i]) == str:
        dictionary_home_coach[df.identifier[i]] = df.home_coach[i]

        
dictionary_guest_coach = {}
for i in range(len(df.date)):
    if type(df.guest_coach[i]) == str:
        dictionary_guest_coach[df.identifier[i]] = df.guest_coach[i]

        
dictionary_home_game_system = {}
for i in range(len(df.date)):
    if type(df.home_game_system[i]) == str:
        dictionary_home_game_system[df.identifier[i]] = df.home_game_system[i]


dictionary_guest_game_system = {}
for i in range(len(df.date)):
    if type(df.guest_game_system[i]) == str:
        dictionary_guest_game_system[df.identifier[i]] = df.guest_game_system[i]

# %%
df.home_coach = df.identifier.map(dictionary_home_coach)
df.guest_coach = df.identifier.map(dictionary_guest_coach)
df.home_game_system = df.identifier.map(dictionary_home_game_system)
df.guest_game_system = df.identifier.map(dictionary_guest_game_system)

# %%
df.shape
# Out:
# (4549, 20)

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2606 entries, 0 to 4548
# Data columns (total 20 columns):
# competition          2606 non-null object
# date                 2606 non-null datetime64[ns]
# gameday              2606 non-null object
# guest_coach          2370 non-null object
# guest_game_system    2367 non-null object
# guest_team_id        2606 non-null int64
# guest_team_name      2606 non-null object
# home_coach           2179 non-null object
# home_game_system     2175 non-null object
# home_team_id         2606 non-null int64
# home_team_name       2606 non-null object
# identifier           2606 non-null object
# result               2606 non-null object
# saison               2606 non-null object
# time                 2606 non-null object
# viewers              2606 non-null int64
# weekday              2606 non-null int64
# day                  2606 non-null int64
# month                2606 non-null int64
# year                 2606 non-null int64
# dtypes: datetime64[ns](1), int64(7), object(12)
# memory usage: 427.5+ KB

# %%
df.head()
# Out:
#   competition                date gameday           guest_coach  \
# 0     2. Liga 2009-07-14 19:00:00       1          Peter Stöger
# 1     2. Liga 2009-07-17 18:00:00       2       Michael Fuchs †
# 2     2. Liga 2009-07-24 18:00:00       3  Bruno Friesenbichler
# 3     2. Liga 2009-07-31 18:00:00       4       Michael Fuchs †
# 4     2. Liga 2009-08-08 17:00:00       5            Adi Hütter
#
#   guest_game_system  guest_team_id      guest_team_name       home_coach  \
# 0           3-4-2-1           2364      First Vienna FC  Michael Fuchs †
# 1             4-5-1           5192          FC Gratkorn       Niko Kovac
# 2             4-4-2           4467         TSV Hartberg  Michael Fuchs †
# 3    4-3-3 defensiv           5192          FC Gratkorn     Edmund Stöhr
# 4          4-2-3-1            3551  SC Rheindorf Altach  Michael Fuchs †
#
#   home_game_system  home_team_id             home_team_name  \
# 0            4-4-2          5192                FC Gratkorn
# 1            3-5-2          6227  Red Bull Juniors Salzburg
# 2      4-4-2 Raute          5192                FC Gratkorn
# 3   4-4-2 doppel 6           541        SC Austria Lustenau
# 4            4-4-2          5192                FC Gratkorn
#
#                                           identifier result   saison   time  \
# 0  4c0f0ae86edebb6bcc1ad9c5d833e0055eea9911b86e5a...    1:1  2009/10  19:00
# 1  23c2ed48d6acf618f5a985662d4841d3eca5ac6a93327b...    3:3  2009/10  18:00
# 2  54806304f66469bdc7b58fe72f800df0eb416eb74249df...    0:0  2009/10  18:00
# 3  34194b3d3200c826828639f67b15c0bfb85696bb2a9f4a...    2:1  2009/10  18:00
# 4  63ec3baaf729fdf854bc02ed1c0d83b7c4de76bd5c5af0...    3:1  2009/10  17:00
#
#    viewers  weekday  day  month  year
# 0     1000        1   14      7  2009
# 1      200        4   17      7  2009
# 2     1200        4   24      7  2009
# 3     2600        4   31      7  2009
# 4     1100        5    8      8  2009

# %%
df.to_csv('zweite_komplett' + '_clean.csv')
